# %%
#matplotlib,seaborn=>important from interview___,plotly >> interactive,bokeh
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.style.use('classic')

# %%
x = np.random.rand(50)
y = np.random.rand(50)

# %%
x
# Out:
# array([0.71427252, 0.1792494 , 0.78364869, 0.62373333, 0.02808087,
#        0.44659842, 0.9484033 , 0.70513204, 0.05492364, 0.91524198,
#        0.73011891, 0.58406005, 0.96243824, 0.46677841, 0.39412042,
#        0.96136361, 0.00642345, 0.00334938, 0.23932332, 0.87161867,
#        0.8250687 , 0.09514707, 0.52962234, 0.86401099, 0.72033373,
#        0.07022938, 0.62629519, 0.82183339, 0.24341036, 0.34097954,
#        0.02470475, 0.72839533, 0.36697474, 0.9793464 , 0.60729237,
#        0.54574087, 0.69358414, 0.86529913, 0.40559047, 0.45615235,
#        0.16395378, 0.58145539, 0.00982659, 0.73779667, 0.71714755,
#        0.49209453, 0.04563724, 0.3454744 , 0.86006579, 0.58174054])

# %%
y
# Out:
# array([0.57785187, 0.8071327 , 0.8958388 , 0.0296477 , 0.99791743,
#        0.64831165, 0.05041951, 0.4773901 , 0.03345401, 0.22799958,
#        0.58981681, 0.5126588 , 0.97599267, 0.55354254, 0.71377781,
#        0.18491554, 0.3446048 , 0.20429902, 0.44111148, 0.50363266,
#        0.40766681, 0.95285062, 0.95667635, 0.26649839, 0.95368986,
#        0.82695873, 0.51115929, 0.06727935, 0.71953698, 0.78770191,
#        0.033644  , 0.26149602, 0.62555972, 0.56572226, 0.75333755,
#        0.33792145, 0.99359036, 0.01262549, 0.29384434, 0.37354065,
#        0.90485229, 0.81822655, 0.24336716, 0.12250678, 0.79975029,
#        0.56429544, 0.6073908 , 0.48959392, 0.76696677, 0.03782543])

# %%
plt.scatter(x,y)

# %%
df =pd.DataFrame(np.random.randn(1000),columns = ['data'],index = pd.date_range('2020/04/21',periods = 1000))

# %%
df.plot(figsize = ( 20,8))
# Out:
# <Axes: >

# %%
x = np.linspace(0,10,100)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
plt.plot(x,np.sin(x))#is nothing but a paper page

# %%
plt.plot(x,np.cos(x))

# %%
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))

# %%
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))
plt.plot(x,np.tan(x))

# %%
plt.plot(x,np.sin(x), '-')

# %%
plt.plot(x,np.sin(x), '--')

# %%
plt.plot(x,np.sin(x), '.-')

# %%
plt.plot(x,np.sin(x), ':')

# %%
plt.figure()
plt.subplot(1,2,1)#on one page make 2 subpart and access 1 subpart
plt.plot(x,np.sin(x))
#1st Part which give me a sin() part// 2nd Part which gives me a cos() part
plt.subplot(1,2,2)
plt.plot(x,np.cos(x))

plt.show()

# %%
plt.figure()

plt.subplot(2,2,1)#on one page 4 subpart 2X2 array access 1st
plt.plot(x,np.sin(x))

plt.subplot(2,2,2)#on one page 4 subpart 2X2 array access 2nd
plt.plot(x,np.cos(x))

plt.subplot(2,2,3)#on one page 4 subpart 2X2 array access 3rd
plt.plot(x,np.tan(x))

plt.subplot(2,2,4)##on one page 4 subpart 2X2 array access 4rth
plt.plot(x,np.cos(x+1))

plt.show()

# %%
plt.figure()

plt.subplot(2,1,1)#on one page 4 subpart 2X2 array access 1st
plt.plot(x,np.sin(x))

plt.subplot(2,1,2)#on one page 4 subpart 2X2 array access 2nd
plt.plot(x,np.cos(x))

# %%
plt.plot(x,np.sin(x-0),color = 'blue')
plt.plot(x,np.cos(x-1),color = 'green')
plt.plot(x,np.sin(x-2),color = (1.0,0.5,0))

# %%
#change the limit of x and y
plt.plot(x,np.sin(x-0),color = 'blue')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.show()

# %%
#both axis are equal reduce space fill empty space
plt.plot(x,np.sin(x-0),color = 'blue')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.axis('equal')
plt.show()

# %%
plt.plot(x,np.sin(x-0),color = 'blue')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.axis('equal')
plt.grid()
plt.show()

# %%
plt.plot(x,np.sin(x-0),color = 'blue')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.axis('equal')
plt.grid()
plt.title("This is Sin Plot before real dataset executioin to undersatand basic syntax")
plt.show()

# %%
plt.plot(x,np.sin(x-0),color = 'blue')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.axis('equal')
plt.grid()
plt.title("This is Sin Plot before real dataset executioin to undersatand basic syntax")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()

# %%
plt.plot(x,np.sin(x-0),color = 'blue',label = 'Sinx')
plt.plot(x,np.cos(x-0),color = 'red',label = 'Cosx')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
#plt.axis('equal')
plt.grid()
plt.title("This is Sin Plot before real dataset executioin to undersatand basic syntax")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.legend()
plt.show()

# %%
#Histogram
#For Contineous Data we will make Histogram or Distribution plot
#By default to create 10 beams
#For each bean count the values in that range
data = np.random.randn(1000)
plt.hist(data)
plt.show()

# %%
data = np.random.randn(1000)
plt.hist(data,bins = 20,histtype='barstacked')
plt.show()

# %%
data = np.random.randn(1000)
plt.hist(data,bins = 20,color='red')
plt.show()

# %%
data = np.random.randn(1000)
plt.hist(data,bins = 20,histtype='step',color='red')
plt.show()

# %%
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
x = np.random.rand(50)
y = np.random.rand(50)

# %%
plt.figure(figsize = (10,10))
plt.scatter(x,y,c='r',alpha = .9,marker = 'x')#alpha = control the intensity of the color
plt.xlabel('X - axis')
plt.ylabel('Y - Axis')
plt.title('ScatterPlot')
plt.show()

# %%
x
# Out:
# array([0.51228935, 0.13022114, 0.41798285, 0.81985305, 0.38813981,
#        0.85971657, 0.55632371, 0.28909122, 0.72550279, 0.99591066,
#        0.87111774, 0.70823369, 0.71538939, 0.18228997, 0.98740101,
#        0.74311416, 0.7632296 , 0.06867728, 0.69449765, 0.86044137,
#        0.41515639, 0.87463058, 0.81615408, 0.52334222, 0.35128208,
#        0.75662516, 0.90161364, 0.66208089, 0.14868396, 0.01238619,
#        0.55040858, 0.77607067, 0.29264127, 0.69576411, 0.12964972,
#        0.48040728, 0.12687981, 0.68436864, 0.73070607, 0.35553955,
#        0.41606104, 0.8428367 , 0.29033761, 0.42976706, 0.70150726,
#        0.64691396, 0.52625254, 0.64261095, 0.33422951, 0.07775572])

# %%
y
# Out:
# array([0.04611086, 0.77895073, 0.35622166, 0.00959325, 0.8166151 ,
#        0.67188318, 0.8213001 , 0.14362905, 0.19023942, 0.9573795 ,
#        0.66231715, 0.5402477 , 0.76966591, 0.12717525, 0.37504822,
#        0.45045901, 0.53658808, 0.19015496, 0.12133279, 0.50990258,
#        0.06300564, 0.06529605, 0.86425137, 0.50825957, 0.28938424,
#        0.92150432, 0.47172711, 0.23839818, 0.04341531, 0.53794709,
#        0.46753708, 0.45685009, 0.59704488, 0.40701078, 0.64703392,
#        0.53161241, 0.79217451, 0.33238391, 0.24184537, 0.07027649,
#        0.16616857, 0.9654545 , 0.76754825, 0.27509413, 0.99787338,
#        0.70587223, 0.36338599, 0.30803507, 0.63635278, 0.32868094])

# %%
x = ['a','b','c','d'] #category
y = [3,4,1,6] #count

# %%
x
# Out:
# ['a', 'b', 'c', 'd']

# %%
y
# Out:
# [3, 4, 1, 6]

# %%
plt.figure(figsize = ( 6, 3))
plt.bar(x,y,color = 'r')
plt.show()

# %%
plt.figure(figsize = ( 6, 3))
plt.bar(x,y,color = 'g')
plt.show()

# %%
plt.figure(figsize = ( 6, 3))
plt.bar(x,y,color = '#FF5733')
plt.title("This is My Bar Plot")
plt.show()

# %%
plt.figure(figsize = ( 6, 3))
plt.barh(x,y,color = '#FF5733')
plt.title("This is My Bar Plot")
plt.show()

# %%
data = [1,2,3,3,3,3,4,5,6,7,8]
plt.hist(data)#ploting is according to the count of the data
plt.show()

# %%
#3D Plot
x = np.random.rand(20)
y = np.random.rand(20)
z = np.random.rand(20)

fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x,y,z,c= '#FF5733',alpha =.9)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.show()

# %%
#Pychart
langs = ['C','Python','Java']
stud = [20,100,40]
#circulat knows widge
plt.pie(stud,labels = langs,autopct = '%1.1f%%')
plt.title('Pie Chart')
plt.show()

# %%
my_explode = (0.0,0.1,0.1)


langs = ['C','Python','Java']
stud = [20,100,40]
#circulat knows widge
plt.pie(stud,labels = langs,autopct = '%1.1f%%',explode = my_explode,shadow=True)
plt.title('Pie Chart')
plt.show()

# %%
x
# Out:
# array([0.98046867, 0.16562361, 0.12793708, 0.31763841, 0.52050833,
#        0.86192233, 0.4020518 , 0.30304189, 0.41427634, 0.86765942,
#        0.12178489, 0.78092337, 0.41331081, 0.77692553, 0.78737011,
#        0.95550435, 0.72652219, 0.66485152, 0.76351757, 0.58985379])

# %%
y
# Out:
# array([0.23849043, 0.38645368, 0.93263636, 0.27215873, 0.93651305,
#        0.70714884, 0.09526594, 0.81744198, 0.76750276, 0.0294094 ,
#        0.07075253, 0.36862313, 0.90597121, 0.11440791, 0.64561833,
#        0.85819501, 0.57528965, 0.278812  , 0.70269053, 0.12017789])

# %%
z
# Out:
# array([0.4945809 , 0.42964919, 0.43990695, 0.11726411, 0.52396156,
#        0.64195731, 0.62425796, 0.7713902 , 0.74301882, 0.11291508,
#        0.38175848, 0.23201844, 0.92846136, 0.76675329, 0.66279317,
#        0.70229268, 0.48535913, 0.45333747, 0.12635727, 0.73414091])

# %% [markdown]
# Performing Operation on Dataset

# %%
df = pd.read_csv("Bank_churn.csv")

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df.plot.scatter(x = 'Age',y = 'Balance')
#insights
#maximum comcentration which age group having most salary =>25 to 40
#maximum balance in the bank having age 40
#min balance is 0 it is present in a all age group
# Out:
# C:\Users\boras\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1258: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='Age', ylabel='Balance'>

# %%
#Age Distribution
plt.title("Age Distribution")
plt.hist(df['Age'],color = 'r')
plt.show()

plt.title("Balance Distribution")
plt.hist(df['Balance'],color = 'cyan')
plt.show()

# %%
df.boxplot(column='Balance')#matplotlib boxplot
# Out:
# <Axes: >

# %%
plt.violinplot(df['Balance'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x184f13e4890>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x184f13e4b10>,
#  'cmins': <matplotlib.collections.LineCollection at 0x184d4443550>,
#  'cbars': <matplotlib.collections.LineCollection at 0x184f2c4cc10>}

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.distplot(tips['total_bill'])
#Kernal Density Distributor
# Out:
# C:\Users\boras\AppData\Local\Temp\ipykernel_12644\4271412032.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips["total_bill"],kde = False,bins=30)
# Out:
# C:\Users\boras\AppData\Local\Temp\ipykernel_12644\2688324828.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips["total_bill"],kde = False,bins=30)
# <Axes: xlabel='total_bill'>

# %%
sns.scatterplot(x=tips.total_bill,y=tips.tip)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(x=tips.total_bill,y=tips.tip,data = tips, hue = 'smoker')
#hue => parameter which can actually differentiate actual data
# Out:
# C:\Users\boras\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x=tips.total_bill,y=tips.tip,data = tips, hue = 'size')
# Out:
# C:\Users\boras\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x=tips.total_bill,y=tips.tip,data = tips, style = 'size')
# Out:
# C:\Users\boras\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x=tips.total_bill,y=tips.tip,data = tips, style = 'smoker',hue = 'time')
# Out:
# C:\Users\boras\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(x='day',y = 'total_bill',data=tips)
# Out:
# C:\Users\boras\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.barplot(x='day',y = 'total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.jointplot(x = tips.total_bill, y = tips.tip)

# %%
sns.jointplot(x = tips.total_bill, y = tips.tip,hue=tips.smoker)

# %%
sns.jointplot(x = tips.total_bill, y = tips.tip,data = tips, kind = 'reg')

# %%
sns.jointplot(x = tips.total_bill, y = tips.tip,data=tips,kind= 'hex')

# %%
sns.jointplot(x = tips.total_bill, y = tips.tip,data=tips,kind= 'kde')#meterological,geophysics
#at center the density is more

# %%
#PairPlot=>>it will plot the pairwise relationship of the dataframe

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(tips)
#if the values are same it give in the form of hist plot
# Out:
# C:\Users\boras\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(tips,hue='sex')
# Out:
# C:\Users\boras\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(tips,hue='smoker')
# Out:
# C:\Users\boras\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(tips,hue='smoker',palette = 'coolwarm')
# Out:
# C:\Users\boras\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#BoxPlot-->to determine the outliers
#1,2,3,4,5,100 >> extreme data

sns.boxplot(x = 'day', y = 'total_bill',data = tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data = tips,orient='h')
# Out:
# <Axes: >

# %%
#correlation >> to understand the relationship between two var x is increasing y is increasing of not
tips_num=tips[['total_bill','tip','size']]

# %%
tips_num.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips_num.corr(),annot = True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.lmplot(x = 'total_bill',y='tip',data=tips,height=15)
# Out:
# C:\Users\boras\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x = 'day', y = 'tip',data = tips,kind ='swarm')
# Out:
# C:\Users\boras\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\boras\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\boras\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 9.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
