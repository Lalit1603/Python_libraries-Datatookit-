# %%
import pandas as pd
import numpy as np

# %%
#REad the data
#read the data type
#first and last rows of data
#business understanding of data
#statastical check

# %%
#json-javascript object notation
dict1={"Name":["Mohit","Akanksha"],
  "Class":"FSDS Pro"
}

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
pd.read_json(url)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
import requests
data=requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
df=data.json()

# %%
df
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58091',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58091/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58091/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58091/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/58091',
#   'id': 2216730815,
#   'node_id': 'PR_kwDOAA0YD85rPMrj',
#   'number': 58091,
#   'title': 'DOC: Changed ndim to 1, modified doc as suggested. #57088',
#   'user': {'login': 'lamprinikourou',
#    'id': 127689412,
#    'node_id': 'U_kgDOB5xixA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/127689412?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lamprinikourou',
#    'html_url': 'https://github.com/lamprinikourou',
# ...

# %%
len(df)
# Out:
# 30

# %%
for i in range(len(df)):
    print(df[i])
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58091', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58091/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58091/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58091/events', 'html_url': 'https://github.com/pandas-dev/pandas/pull/58091', 'id': 2216730815, 'node_id': 'PR_kwDOAA0YD85rPMrj', 'number': 58091, 'title': 'DOC: Changed ndim to 1, modified doc as suggested. #57088', 'user': {'login': 'lamprinikourou', 'id': 127689412, 'node_id': 'U_kgDOB5xixA', 'avatar_url': 'https://avatars.githubusercontent.com/u/127689412?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/lamprinikourou', 'html_url': 'https://github.com/lamprinikourou', 'followers_url': 'https://api.github.com/users/lamprinikourou/followers', 'following_url': 'https://api.github.com/users/
# ...

# %%
for i in range(len(df)):
    print(df[i]['user'])
# Out:
# {'login': 'lamprinikourou', 'id': 127689412, 'node_id': 'U_kgDOB5xixA', 'avatar_url': 'https://avatars.githubusercontent.com/u/127689412?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/lamprinikourou', 'html_url': 'https://github.com/lamprinikourou', 'followers_url': 'https://api.github.com/users/lamprinikourou/followers', 'following_url': 'https://api.github.com/users/lamprinikourou/following{/other_user}', 'gists_url': 'https://api.github.com/users/lamprinikourou/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/lamprinikourou/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/lamprinikourou/subscriptions', 'organizations_url': 'https://api.github.com/users/lamprinikourou/orgs', 'repos_url': 'https://api.github.com/users/lamprinikourou/repos', 'events_url': 'https://api.github.com/users/lamprinikourou/events{/privacy}', 'received_events_url': 'https://api.github.com/users/lamprinikourou/received_events', 'type': 'User', 'site_admi
# ...

# %%
for i in range(len(df)):
    print(df[i]['user']['node_id'])
# Out:
# U_kgDOB5xixA
# MDQ6VXNlcjUyNzkyOTk5
# MDQ6VXNlcjgwNzg5Njg=
# U_kgDOB2aEBg
# MDQ6VXNlcjQ3OTYzMjE1
# MDQ6VXNlcjE0MDc1OTIy
# MDQ6VXNlcjQ1NTYyNDAy
# U_kgDOByhD2w
# MDQ6VXNlcjkxMTYwNDc1
# MDQ6VXNlcjI1NDY1NDM=
# MDQ6VXNlcjUyNzkyOTk5
# MDQ6VXNlcjM5NTA0MjMz
# MDQ6VXNlcjUyNzkyOTk5
# MDQ6VXNlcjY1NjI1MzQ4
# MDQ6VXNlcjE4MTM1MzQ4
# MDQ6VXNlcjYwNjA5ODc5
# MDQ6VXNlcjEwMjA0OTY=
# U_kgDOCduQxA
# MDQ6VXNlcjEzMDQ5NTA=
# MDQ6VXNlcjMyNDcxNzk=
# MDQ6VXNlcjM1NjEzNDg3
# MDQ6VXNlcjM1NjEzNDg3
# MDQ6VXNlcjM1NjEzNDg3
# MDQ6VXNlcjM1NjEzNDg3
# MDQ6VXNlcjM1NjEzNDg3
# MDQ6VXNlcjM1NjEzNDg3
# MDQ6VXNlcjEwMzQxNzQ3
# MDQ6VXNlcjgwODk2NjU1
# MDQ6VXNlcjMyNDcxNzk=
# MDQ6VXNlcjgwNzg5Njg=

# %%
pd.DataFrame(df)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
df1=pd.DataFrame(df,columns=['user','timeline_url'])

# %%
df1.to_csv('json_info.csv')

# %%
df1.to_excel('json_excel.xlsx')

# %%
#Solving the dataset

# %%
df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File ~\anaconda3\Lib\http\client.py:1286, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1285 """Send a complete request to the server."""
# -> 1286 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\anaconda3\Lib\http\client.py:1332, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1331     body = _encode(body, 'body')
# -> 1332 self.endheaders(body, encode_chunked=encode_chunked)
#
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()#describe a numerical data
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#no of children died and survived below 5 yrs
#in age col min age is means 0.420000 means 4 months 20days yr old
#25%-the percentage of people below that number.25% of people are equal to or below the age of 20 yr's old
#50%-the percentage of people below that number.50% of people are equal to or below the age of 28 yr's old
#75%-the percentage of people below that number.75% of people are equal to or below the age of 38 yr's old
#max:-the oldest person was died in that incident is 80 yr's old

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[['PassengerId', 'Survived', 'Pclass']]
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
# [891 rows x 3 columns]

# %%
df.dtypes=='object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
type(df.dtypes=='object')
# Out:
# pandas.core.series.Series

# %%
[df.dtypes=='object'].index
# Out:
# <function list.index(value, start=0, stop=9223372036854775807, /)>

# %%
df.dtypes[df.dtypes=='object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[df.dtypes[df.dtypes=='object'].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df[df.columns[df.dtypes=='object']]#alternative way
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df[df.columns[df.dtypes!='object']]
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
df[df.dtypes[df.dtypes!='object'].index]
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
df[df.dtypes[df.dtypes!='object'].index].describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df[df.dtypes[df.dtypes=='object'].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
#might have null val,it means in 1 cabin multiple passangers

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(include='object')
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
df.astype('object').describe()
# Out:
#         PassengerId  Survived  Pclass                     Name   Sex    Age  \
# count           891       891     891                      891   891  714.0
# unique          891         2       3                      891     2   88.0
# top               1         0       3  Braund, Mr. Owen Harris  male   24.0
# freq              1       549     491                        1   577   30.0
#
#         SibSp  Parch  Ticket    Fare    Cabin Embarked
# count     891    891     891  891.00      204      889
# unique      7      7     681  248.00      147        3
# top         0      0  347082    8.05  B96 B98        S
# freq      608    678       7   43.00        4      644

# %%
========================================================================================================

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.astype('object').describe()#all col's converted into object
# Out:
#         PassengerId  Survived  Pclass                     Name   Sex    Age  \
# count           891       891     891                      891   891  714.0
# unique          891         2       3                      891     2   88.0
# top               1         0       3  Braund, Mr. Owen Harris  male   24.0
# freq              1       549     491                        1   577   30.0
#
#         SibSp  Parch  Ticket    Fare    Cabin Embarked
# count     891    891     891  891.00      204      889
# unique      7      7     681  248.00      147        3
# top         0      0  347082    8.05  B96 B98        S
# freq      608    678       7   43.00        4      644

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df[1:10]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# ...

# %%
df[10:100]
# Out:
#     PassengerId  Survived  Pclass                                  Name  \
# 10           11         1       3       Sandstrom, Miss. Marguerite Rut
# 11           12         1       1              Bonnell, Miss. Elizabeth
# 12           13         0       3        Saundercock, Mr. William Henry
# 13           14         0       3           Andersson, Mr. Anders Johan
# 14           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# ..          ...       ...     ...                                   ...
# 95           96         0       3           Shorney, Mr. Charles Joseph
# 96           97         0       1             Goldschmidt, Mr. George B
# 97           98         1       1       Greenfield, Mr. William Bertram
# 98           99         1       2  Doling, Mrs. John T (Ada Julia Bone)
# 99          100         0       2                     Kantor, Mr. Sinai
#
#        Sex   Age  SibSp  Parch     Ticket     Fare    Cabin Embarked
# ...

# %%
df[10:100:2]
# Out:
#     PassengerId  Survived  Pclass  \
# 10           11         1       3
# 12           13         0       3
# 14           15         0       3
# 16           17         0       3
# 18           19         0       3
# 20           21         0       2
# 22           23         1       3
# 24           25         0       3
# 26           27         0       3
# 28           29         1       3
# 30           31         0       1
# 32           33         1       3
# 34           35         0       1
# 36           37         1       3
# 38           39         0       3
# 40           41         0       3
# 42           43         0       3
# 44           45         1       3
# 46           47         0       3
# 48           49         0       3
# 50           51         0       3
# 52           53         1       1
# 54           55         0       1
# 56           57         1       2
# 58           59         1       2
# 60           61         0       3
# ...

# %%
df['new_col']="Lalit"

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['family'] = df['SibSp'] + df['Parch']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
pd.Categorical(df['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
pd.Categorical(df['Cabin'])
# Out:
# [NaN, 'C85', NaN, 'C123', NaN, ..., NaN, 'B42', NaN, 'C148', NaN]
# Length: 891
# Categories (147, object): ['A10', 'A14', 'A16', 'A19', ..., 'F38', 'F4', 'G6', 'T']

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df['Cabin'].nunique()
# Out:
# 147

# %%
df['Cabin'].value_counts()
# Out:
# Cabin
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
#Q1.How many passangers are less than 5 yrs old

# %%
df['Age'] < 5
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df[df['Age']<5]

# %%
len(df[df['Age']<5])
# Out:
# 40

# %%
#No.of passengers > 18
df[df['Age']>18]

# %%
len(df[df['Age']>18])

# %%
#how many passengers are less than 18 yrs old
len(df) - len(df[df['Age']>=18])
# Out:
# 290

# %%
len(df[df['Age'] <= 18])
# Out:
# 139

# %%
#Q.How many passengers have paid less than avg fare
#calculate avg fare
df['Fare'].mean()
# Out:
# 32.204207968574636

# %%
df.describe().mean()
# Out:
# PassengerId    478.044230
# Survived       111.733804
# Pclass         113.268089
# Age            115.596327
# SibSp          112.703219
# Parch          112.273456
# Fare           192.323930
# family         113.064758
# dtype: float64

# %%
df[df['Fare']<df['Fare'].mean()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
len(df[df['Fare']<df['Fare'].mean()])
# Out:
# 680

# %%
df[df['Fare'] < 32]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df[df['Fare']>df['Fare'].mean()]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 23            24         1       1
# 27            28         0       1
# ..           ...       ...     ...
# 856          857         1       1
# 863          864         0       3
# 867          868         0       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# ..                                                 ...     ...   ...    ...
# ...

# %%
len(df[df['Fare']>df['Fare'].mean()])

# %%
#Q.How Many Passengers paid 0 fare
df[df['Fare'] == 0]

# %%
len(df[df['Fare'] == 0])

# %%
df[df['Fare'] == 0].Name

# %%
list(df[df['Fare'] == 0].Name)
# Out:
# ['Leonard, Mr. Lionel',
#  'Harrison, Mr. William',
#  'Tornquist, Mr. William Henry',
#  'Parkes, Mr. Francis "Frank"',
#  'Johnson, Mr. William Cahoone Jr',
#  'Cunningham, Mr. Alfred Fleming',
#  'Campbell, Mr. William',
#  'Frost, Mr. Anthony Wood "Archie"',
#  'Johnson, Mr. Alfred',
#  'Parr, Mr. William Henry Marsh',
#  'Watson, Mr. Ennis Hastings',
#  'Knight, Mr. Robert J',
#  'Andrews, Mr. Thomas Jr',
#  'Fry, Mr. Richard',
#  'Reuchlin, Jonkheer. John George']

# %%
#How Many Passengers are male and female

len(df[df['Sex']=='male'])

# %%
len(df[df['Sex']=='female'])

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df['Sex'].value_counts(normalize=True)
# Out:
# Sex
# male      0.647587
# female    0.352413
# Name: proportion, dtype: float64

# %%
df['Sex'].value_counts(normalize=True).male

# %%
df['Sex'].value_counts(normalize=True).female

# %%
#Q.How many passengers of class 1

df[df['Pclass']==1]

# %%
df[df['Survived']==1]

# %%
len(df[df['Survived']==1])
# Out:
# 342

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Survived'].value_counts(normalize=True)
# Out:
# Survived
# 0    0.616162
# 1    0.383838
# Name: proportion, dtype: float64

# %%
#How Many femails paid more than avg fare
df['Fare'].mean()

# %%
df[(df['Sex']=='female') & (df['Fare'] > df['Fare'].mean())]

# %%
#Qn.How Many Passenger are Male or Greter than avg fare
df[(df['Sex']=='male') | (df['Fare'] > df['Fare'].mean())]

# %%
#How Many Pass are Male and greater than avg  fair
df[(df['Sex']=='male') & (df['Fare'] > df['Fare'].mean())]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 6              7         0       1               McCarthy, Mr. Timothy J
# 23            24         1       1          Sloper, Mr. William Thompson
# 27            28         0       1        Fortune, Mr. Charles Alexander
# 34            35         0       1               Meyer, Mr. Edgar Joseph
# 35            36         0       1        Holverson, Mr. Alexander Oskar
# ..           ...       ...     ...                                   ...
# 827          828         1       2                 Mallet, Master. Andre
# 838          839         1       3                       Chip, Mr. Chang
# 846          847         0       3              Sage, Mr. Douglas Bullen
# 848          849         0       2                     Harper, Rev. John
# 867          868         0       1  Roebling, Mr. Washington Augustus II
#
#       Sex   Age  SibSp  Parch           Ticket      Fare        Cabin  \
# ...

# %%
np.mean(df['Fare'])
# Out:
# 32.204207968574636

# %%
df['Fare'].mean()

# %%
max(df['Fare'])

# %%
min(df['Fare'])

# %%
#who are the passengers who paid maximum fare
df[df['Fare']==max(df['Fare'])]['Name']

# %%
"""Qn.How Many Passengers have parch greater than 3
   Qn.How Many Passengers who survived paid the maximum fare
   Qn.How many Passengers who didnt survived was from class 1
   Qn.How many Passengers are having children (<5 years old)
"""

# %%
#Access df rows
df[0:100:2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #Access df rows
# ----> 2 df[0:100:2]
#
# NameError: name 'df' is not defined

# %%
#implicit index(internal/interger index) and explicit index(that were defined by us)/named indexing/name

# %%
df = pd.read_csv("C:\\Users\\boras\\Downloads\\titanic.csv")

# %%
df.iloc[0:2] # start from 0 go to 1 excluding 2/iloc is integer index/inplicit index
#istand for interger indexing
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.loc[0:2] # give me the rows whose name is 0,1,2 #location treat as name,loc is named index/explicit index
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
#loc will go with named index, iloc will go with inbuilt index

# %%
df.iloc[0:2,['Name','Sex','Age']]#it throws thee error

# %%
df.loc[0:2,['Name','Sex','Age']]
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0

# %%
df

# %%
df.iloc[0:2,3:6]
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0

# %%
df.iloc[0:2,[0,1,2,3,4,5]]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0

# %%
df['Name'][2:14]
# Out:
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# 11                             Bonnell, Miss. Elizabeth
# 12                       Saundercock, Mr. William Henry
# 13                          Andersson, Mr. Anders Johan
# Name: Name, dtype: object

# %%
len(df['Name'][2:14])
# Out:
# 12

# %%
list(df['Name'][2:5])
# Out:
# ['Heikkinen, Miss. Laina',
#  'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#  'Allen, Mr. William Henry']

# %%
s=pd.Series(list(df['Name'][2:5]),index=['a','b','c'])

# %%
s

# %%
type(s)

# %%
s1=pd.Series(list(df['Name'][5:8]),index=['a','b','c'])

# %%
s1
# Out:
# a                  Moran, Mr. James
# b           McCarthy, Mr. Timothy J
# c    Palsson, Master. Gosta Leonard
# dtype: object

# %%
s+s1
# Out:
# a               Heikkinen, Miss. LainaMoran, Mr. James
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)Mc...
# c    Allen, Mr. William HenryPalsson, Master. Gosta...
# dtype: object

# %%
s=pd.Series(list(df['Name'][2:5]),index=['a','b','c'])

# %%
s1=pd.Series(list(df['Name'][5:8]))

# %%
s+s1#series or dataframe doesn't work with +
# Out:
# a    NaN
# b    NaN
# c    NaN
# 0    NaN
# 1    NaN
# 2    NaN
# dtype: object

# %%
pd.concat([s,s1])
# Out:
# a                          Heikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# 0                                Moran, Mr. James
# 1                         McCarthy, Mr. Timothy J
# 2                  Palsson, Master. Gosta Leonard
# dtype: object

# %%
#s.append(s1)
pd.concat([s,s1])
# Out:
# a                          Heikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# 0                                Moran, Mr. James
# 1                         McCarthy, Mr. Timothy J
# 2                  Palsson, Master. Gosta Leonard
# dtype: object

# %%
#new

# %%
s=pd.Series(list(df['Name'][2:5]),index=['a','b','c'])

# %%
s1=pd.Series(list(df['Name'][5:8]),index=['a','b','c'])

# %%
s+s1

# %%
pd.concat([s,s1])
# Out:
# a                          Heikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# 0                                Moran, Mr. James
# 1                         McCarthy, Mr. Timothy J
# 2                  Palsson, Master. Gosta Leonard
# dtype: object

# %%
df.drop('PassengerId')#row->axis=0 , col->axis->1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df.drop('PassengerId')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...

# %%
df.columns

# %%
df.drop('Unnamed: 0',axis=1)

# %%
df

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df

# %%
df.drop(1,inplace=True)#not can be rollback,consider row as a named index

# %%
df

# %%
df

# %%
df

# %%
#make a name col as index

# %%
df.set_index('Name',inplace=True)#time series data->you will making date time col as index

# %%
df
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df.loc['Allen, Mr. William Henry']
# Out:
# PassengerId         5
# Survived            0
# Pclass              3
# Sex              male
# Age              35.0
# SibSp               0
# Parch               0
# Ticket         373450
# Fare             8.05
# Cabin             NaN
# Embarked            S
# Name: Allen, Mr. William Henry, dtype: object

# %%
df.iloc[1]#at background store the index

# %%
df.head()

# %%
df.reset_index(inplace=True)#it get back again inplicit index again

# %%
df

# %%
#Make a data frame using dict
d = {"key1":[1,2,3,4,9,3],
    "key2":[11,22,33,44,55,66],
    "key3":['a','b','c','d','e','f']}

# %%
d

# %%
pd.DataFrame(d)

# %%
d1= {"key1":(1,2,3,4,9,3),
    "key2":(11,22,33,44,55,66),
    "key3":('a','b','c','d','e','f')}

# %%
d1

# %%
pd.DataFrame(d1)

# %%
df1 = pd.read_csv("taxonomy.csv.xls")

# %%
df1

# %%
df1.shape

# %%
df1.ndim

# %%
df1.info()

# %%
df1.isnull()

# %%
df1.isnull().sum()

# %%
df1

# %%
df1.dropna()

# %%
df1

# %%
df1.dropna(inplace=True)#drop row wise

# %%
df1

# %%
df2=pd.read_csv('taxonomy.csv.xls')

# %%
df2.dropna(axis=1)#col have null value it is droped

# %%
df2

# %%
#when a value are drop will col wise then value are droped by rows also

# %%
df2.dropna(axis=1)

# %%
df2[['name']].dropna(axis=1)#for on col

# %%
df2

# %%
df2.fillna("Missing Value_Here",inplace=True)

# %%
df2

# %%
df

# %%
#Qn.What is the avg fare paid by people who survived?

# %%
#using group by
df.groupby('Survived').mean(numeric_only=True)
# Out:
#           Unnamed: 0  PassengerId    Pclass        Age     SibSp     Parch  \
# Survived
# 0         446.016393   447.016393  2.531876  30.626179  0.553734  0.329690
# 1         443.368421   444.368421  1.950292  28.343690  0.473684  0.464912
#
#                Fare
# Survived
# 0         22.117887
# 1         48.395408

# %%
import pandas as pd
df =pd.read_csv("titanic.csv")

# %%
df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df.groupby('Survived').describe()
# Out:
#          Unnamed: 0                                                            \
#               count        mean         std  min     25%    50%    75%    max
# Survived
# 0             549.0  446.016393  260.640469  0.0  210.00  454.0  674.0  890.0
# 1             342.0  443.368421  252.358840  1.0  249.75  438.5  650.5  889.0
#
#          PassengerId              ... Parch        Fare                        \
#                count        mean  ...   75%  max  count       mean        std
# Survived                          ...
# 0              549.0  447.016393  ...   0.0  6.0  549.0  22.117887  31.388207
# 1              342.0  444.368421  ...   1.0  5.0  342.0  48.395408  66.596998
#
#
#           min      25%   50%   75%       max
# Survived
# 0         0.0   7.8542  10.5  26.0  263.0000
# 1         0.0  12.4750  26.0  57.0  512.3292
#
# [2 rows x 56 columns]

# %%
import numpy as np
df.groupby('Survived').aggregate([min,max,'median','count',np.std,'var'])
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# ...

# %%
#groupby with two cols
#Q.Avg People who servived for each sex(male or female) , pclass

# %%
df.groupby(['Sex','Pclass'])['Survived'].sum()
# Out:
# Sex     Pclass
# female  1         91
#         2         70
#         3         72
# male    1         45
#         2         17
#         3         47
# Name: Survived, dtype: int64

# %%
#female who servived having Passenger class 1 is 91, Passenger Class 2 70 , Passenger class 72
